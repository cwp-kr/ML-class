# %% [markdown]
# <a href="https://colab.research.google.com/github/cwp-kr/ML-class/blob/main/%EC%A4%91%EA%B0%84test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

# %%
X = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/boston_house_data.csv', usecols=['12']).values
y = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/boston_house_target.csv', usecols=['0']).values

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.3)

# %%
plt.figure(figsize = (6, 6))
plt.title('linear Regression', fontsize = 16)
plt.plot(X_train, y_train ,'bo', markersize=4, label='Train data')
plt.plot(X_test, y_test,'go', markersize=4, label='Test data')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
w2 = 0
w3 = 0

n = float(len(X_train))

for i in range(10000):
    y_pred = w3*X_train + w2
    dw3 = (1/n) * sum(X_train * (y_pred-y_train))
    dw2 = (1/n) * sum(y_pred-y_train)
    w3 = w3 - 0.001 * dw3
    w2 = w2 - 0.001 * dw2
print (w3, w2)
# Out:
# [-0.75067742] [31.43970115]

# %%
xp = np.arange(0, 35, 0.01).reshape(-1, 1)
y_pred = w3*xp + w2

plt.figure(figsize = (6, 6))
plt.title('linear Regression', fontsize = 16)
plt.plot(X_train, y_train ,'bo', markersize=4, label='Train data')
plt.plot(X_test, y_test,'go', markersize=4, label='Test data')
plt.plot(xp, y_pred, 'r', linewidth = 2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
clf = linear_model.LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.coef_
# Out:
# array([[-0.91786648]])

# %%
clf.intercept_
# Out:
# array([34.31002628])

# %%
plt.figure(figsize = (6, 6))
plt.title('linear Regression', fontsize = 16)
plt.plot(X_train, y_train ,'bo', markersize=4, label='Train data')
plt.plot(X_test, y_test,'go', markersize=4, label='Test data')
plt.plot(xp, clf.predict(xp), 'r', linewidth = 2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %% [markdown]
# 비선형

# %%
m0 = 0
m1 = 0
m2 = 0

n = float(len(X_train))

for i in range(1000):
    y_pred1 = m2*X_train**2 + m1*X_train + m0
    dm2 = (1/n) * sum(X_train**2 * (y_pred1-y_train))
    dm1 = (1/n) * sum(X_train * (y_pred1-y_train))
    dm0 = (1/n) * sum(y_pred1-y_train)
    m2 = m2 - 0.00001 * dm2
    m1 = m1 - 0.00001 * dm1
    m0 = m0 - 0.00001 * dm0
print (m2, m1, m0)
# Out:
# [-0.00189537] [0.80004722] [0.13858843]

# %%
xp = np.arange(0, 35, 0.01).reshape(-1, 1)
y_pred1 = m2*xp**2 + m1*xp + m0

plt.figure(figsize = (6, 6))
plt.title('linear Regression', fontsize = 16)
plt.plot(X_train, y_train ,'bo', markersize=4, label='Train data')
plt.plot(X_test, y_test,'go', markersize=4, label='Test data')
plt.plot(xp, y_pred1, 'r', linewidth = 2)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


regressor = LinearRegression()
regressor.fit(X_train, y_train)


y_pred = regressor.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print("Predictions:", y_pred)
print("Mean Squared Error (MSE):", mse)
print("R² Score:", r2)
# Out:
# Predictions: [[27.12313178]
#  [29.27093933]
#  [14.55753972]
#  [30.61102438]
#  [22.34104744]
#  [24.99368155]
#  [23.17630593]
#  [23.53427386]
#  [15.64062216]
#  [23.28644991]
#  [19.81691463]
#  [22.62558604]
#  [30.02358984]
#  [25.15889752]
#  [29.45451263]
#  [22.44201275]
#  [17.46717645]
#  [22.99273263]
#  [31.61149884]
#  [26.82023584]
#  [27.52699303]
#  [27.9767476 ]
#  [23.75456181]
#  [14.74111302]
#  [27.41684905]
#  [ 6.03056016]
#  [21.81786355]
#  [16.86138458]
#  [ 7.06774928]
#  [18.17393364]
#  [18.55943756]
#  [18.53190156]
#  [12.93291606]
#  [19.7710213 ]
#  [26.43473192]
#  [20.7347811 ]
#  [31.57478418]
#  [23.61688184]
#  [21.47825295]
#  [18.59615222]
#  [14.61261171]
#  [26.92120115]
#  [28.26128621]
#  [27.33424107]
#  [25.41590013]
#  [23.58016718]
#  [19.41305338]
#  [26.40719593]
#  [23.95649243]
#  [26.49898257]
#  [26.35212394]
#  [30.49170174]
#  [23.60770317]
#  [20.85410375]
#  [22.57051406]
#  [12.20780154]
#  [11.76722563]
#  [19.89952261]
# ...

# %% [markdown]
# 뒷장

# %%
# %matplotlib inline

C1_X1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C1_X1']).values
C1_X2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C1_X2']).values
C2_X1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C2_X1']).values
C2_X2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C2_X2']).values
C3_X1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C3_X1']).values
C3_X2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C3_X2']).values
C4_X1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C4_X1']).values
C4_X2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C4_X2']).values

X1 = np.hstack((C1_X1, C1_X2))
X2 = np.hstack((C2_X1, C2_X2))
X3 = np.hstack((C3_X1, C3_X2))
X4 = np.hstack((C4_X1, C4_X2))

y1 = 1*np.ones([200,1])
y2 = 2*np.ones([200,1])
y3 = 3*np.ones([200,1])
y4 = 4*np.ones([200,1])

plt.figure(figsize = (6, 4))
plt.title('Generated Data for Multiclass Classification', fontsize=14)
plt.plot(C1_X1, C1_X2, '.', markersize = 4, label = 'Class 1')
plt.plot(C2_X1, C2_X2, '.', markersize = 4, label = 'Class 2')
plt.plot(C3_X1, C3_X2, '.', markersize = 4, label = 'Class 3')
plt.plot(C4_X1, C4_X2, '.', markersize = 4, label = 'Class 4')
plt.xlabel('$X_1$', fontsize = 15)
plt.ylabel('$X_2$', fontsize = 15)
plt.legend(loc=1)
plt.axis('equal')
plt.grid(alpha = 0.3)

plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
clf12 = linear_model.LogisticRegression(solver = 'lbfgs')
clf12.fit(np.vstack([X1, X2]),np.ravel(np.vstack([y1,y2])))

clf13 = linear_model.LogisticRegression(solver = 'lbfgs')
clf13.fit(np.vstack([X1, X3]),np.ravel(np.vstack([y1,y3])))

clf23 = linear_model.LogisticRegression(solver = 'lbfgs')
clf23.fit(np.vstack([X2, X3]),np.ravel(np.vstack([y2,y3])))

clf14 = linear_model.LogisticRegression(solver = 'lbfgs')
clf14.fit(np.vstack([X1, X4]),np.ravel(np.vstack([y1,y4])))

clf24 = linear_model.LogisticRegression(solver = 'lbfgs')
clf24.fit(np.vstack([X2, X4]),np.ravel(np.vstack([y2,y4])))

clf34 = linear_model.LogisticRegression(solver = 'lbfgs')
clf34.fit(np.vstack([X3, X4]),np.ravel(np.vstack([y3,y4])))
# Out:
# LogisticRegression()

# %%
w12 = np.zeros([3,1])
w12[0,0] = clf12.intercept_[0]
w12[1,0] = clf12.coef_[0,0]
w12[2,0] = clf12.coef_[0,1]

w13 = np.zeros([3,1])
w13[0,0] = clf13.intercept_[0]
w13[1,0] = clf13.coef_[0,0]
w13[2,0] = clf13.coef_[0,1]

w23 = np.zeros([3,1])
w23[0,0] = clf23.intercept_[0]
w23[1,0] = clf23.coef_[0,0]
w23[2,0] = clf23.coef_[0,1]

w14 = np.zeros([3,1])
w14[0,0] = clf14.intercept_[0]
w14[1,0] = clf14.coef_[0,0]
w14[2,0] = clf14.coef_[0,1]

w24 = np.zeros([3,1])
w24[0,0] = clf24.intercept_[0]
w24[1,0] = clf24.coef_[0,0]
w24[2,0] = clf24.coef_[0,1]

w34 = np.zeros([3,1])
w34[0,0] = clf34.intercept_[0]
w34[1,0] = clf34.coef_[0,0]
w34[2,0] = clf34.coef_[0,1]

xp = np.linspace(0,10,100).reshape(-1,1)

yp12 = -w12[0,0]/w12[2,0] -w12[1,0]*xp/w12[2,0]
yp13 = -w13[0,0]/w13[2,0] -w13[1,0]*xp/w13[2,0]
yp23 = -w23[0,0]/w23[2,0] -w23[1,0]*xp/w23[2,0]
yp14 = -w14[0,0]/w14[2,0] -w14[1,0]*xp/w14[2,0]
yp24 = -w24[0,0]/w24[2,0] -w24[1,0]*xp/w24[2,0]
yp34 = -w34[0,0]/w34[2,0] -w34[1,0]*xp/w34[2,0]


plt.figure(figsize = (6, 4))
plt.plot(X1[:,0], X1[:,1], '.', markersize = 4, label = 'Class 1')
plt.plot(X2[:,0], X2[:,1], '.', markersize = 4, label = 'Class 2')
plt.plot(X3[:,0], X3[:,1], '.', markersize = 4, label = 'Class 3')
plt.plot(X4[:,0], X4[:,1], '.', markersize = 4, label = 'Class 4')

plt.plot(xp, yp12, 'r--', linewidth = 2, label = '1 vs. 2')
plt.plot(xp, yp13, 'b--', linewidth = 2, label = '1 vs. 3')
plt.plot(xp, yp23, 'm--', linewidth = 2, label = '2 vs. 3')
plt.plot(xp, yp14, 'y--', linewidth = 2, label = '1 vs. 4')
plt.plot(xp, yp24, 'g--', linewidth = 2, label = '2 vs. 4')
plt.plot(xp, yp34, 'b--', linewidth = 2, label = '3 vs. 4')

plt.title('Multiclass Classification')
plt.axis('equal')
plt.grid(alpha = 0.3)
plt.axis([-2, 10, 0, 12])
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
plt.legend(loc = 1)
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
C1_X1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C1_X1']).values
C1_X2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C1_X2']).values
C4_X1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C4_X1']).values
C4_X2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/multivariate_data.csv', usecols=['C4_X2']).values

plt.figure(figsize = (6, 4))
plt.title('Generated Data for Multiclass Classification', fontsize=14)
plt.plot(C1_X1, C1_X2, '.', markersize = 4, label = 'Class 1')
plt.plot(C4_X1, C4_X2, '.', markersize = 4, label = 'Class 0')
plt.xlabel('$X_1$', fontsize = 15)
plt.ylabel('$X_2$', fontsize = 15)
plt.legend(loc=1)
plt.axis('equal')
plt.grid(alpha = 0.3)
plt.show()

# %%
def h(x,w):
    return 1/(1 + np.exp(-x@w))

# %%
C1 = np.hstack((C1_X1, C1_X2))
C1.shape
# Out:
# (200, 2)

# %%
C2 = np.hstack((C4_X1, C4_X2))
C2.shape
# Out:
# (200, 2)

# %%
X = np.vstack((C1,C2))
X.shape
# Out:
# (400, 2)

# %%
a = np.ones([400,1])
a.shape
# Out:
# (400, 1)

# %%
X = np.hstack([a,X])
X.shape
# Out:
# (400, 3)

# %%
y = np.vstack((np.ones([200,1]), np.zeros([200,1])))
y.shape
# Out:
# (400, 1)

# %%
w = np.zeros([3,1])

alpha = 0.01

for i in range(10000):
    df = -X.T@(y - h(X,w))
    w = w - alpha*df

print(w)
# Out:
# [[-16.95130818]
#  [ -7.57377415]
#  [  6.68890611]]

# %%
xp = np.linspace(0,10,100).reshape(-1,1)
yp = - w[1,0]/w[2,0]*xp - w[0,0]/w[2,0]

plt.figure(figsize = (6, 4))
plt.title('Generated Data for Multiclass Classification', fontsize=14)
plt.plot(C1_X1, C1_X2, '.', markersize = 4, label = 'Class 1')
plt.plot(C4_X1, C4_X2, '.', markersize = 4, label = 'Class 0')
plt.plot(xp, yp, 'r', linewidth = 4, label = 'Logistic Regression')
plt.xlabel('$X_1$', fontsize = 15)
plt.ylabel('$X_2$', fontsize = 15)
plt.legend(loc=1)
plt.axis('equal')
plt.ylim(0,15)
plt.grid(alpha = 0.3)
plt.show()
